# %%
# %run greenland_greenhouse_emissions_total.ipynb
# %run greenland_greenhouse_emissions_fuel_combustion.ipynb
# %run greenland_greenhouse_emissions_industrial.ipynb
# %run greenland_greenhouse_emissions_agriculture.ipynb
# %run greenland_greenhouse_emissions_waste.ipynb
# %run greenland_greenhouse_emissions_forest.ipynb

# %% [markdown]
# Different dataframes to concatenate: total_df (ttal net emissions); total_fuel_emissions (total fuel emissions)

# %%
new_df = pd.concat([total_df, total_fuel_emissions, total_industrial_emissions, total_agriculture_emissions, total_waste_emissions, total_forest_emissions], axis=0).drop(columns='emissions_change')

# %%
sector_df = new_df.pivot_table(index='time', columns='sector', values='Greenlands total emission of greenhousegasses')

sector_df.head()
# Out:
# sector  1. Emissions from fuel combustion  2. Industrial Processes  \
# time
# 1990                             625203.0                    515.0
# 1991                             610360.0                    501.0
# 1992                             596179.0                    508.0
# 1993                             545953.0                    560.0
# 1994                             495672.0                    535.0
#
# sector  3. Agriculture  4. Waste  5. Forest and Land Use  \
# time
# 1990            9547.0   17688.0                   262.0
# 1991            9628.0   17816.0                   330.0
# 1992            8657.0   17920.0                   358.0
# 1993            7634.0   18048.0                   386.0
# 1994            8324.0   18217.0                   414.0
#
# sector  Total (net emissions)
# time
# 1990                 653216.0
# 1991                 638634.0
# 1992                 623622.0
# 1993                 572582.0
# 1994                 523162.0

# %%
total_emissions = sector_df['Total (net emissions)'].sum()
fuel_emissions = sector_df['1. Emissions from fuel combustion'].sum()
industrial_emissions = sector_df['2. Industrial Processes'].sum()
agriculture_emissions = sector_df['3. Agriculture'].sum()
waste_emissions = sector_df['4. Waste'].sum()
forest_emissions = sector_df['5. Forest and Land Use'].sum()

# Calculate the percentage of emissions from fuel
percentage_fuel_emissions = (fuel_emissions / total_emissions) * 100

# Calculate the percentage of industrial emissions
percentage_industrial_emissions = (industrial_emissions / total_emissions) * 100

# Calculate the percentage of agriculture emissions
percentage_agriculture_emissions = (agriculture_emissions / total_emissions) * 100

# Calculate the percentage of agriculture emissions
percentage_waste_emissions = (waste_emissions / total_emissions) * 100

# Calculate the percentage of forest and land use emissions
percentage_forest_emissions = (forest_emissions / total_emissions) * 100

# Create labels for the pie chart
labels = ['Fuel Emissions', 'Forest and Land Use Emissions', 'Industrial Emissions', 'Agriculture Emissions', 'Waste Emissions']

# Create sizes for the pie chart
sizes = [percentage_fuel_emissions, percentage_forest_emissions, percentage_industrial_emissions, percentage_agriculture_emissions, percentage_waste_emissions]

# Create the pie chart
plt.figure(figsize=(10, 8))
patches, _ = plt.pie(sizes, startangle=140)
plt.title('Percentage of Emissions from Different Sources')
plt.axis('equal')

# Create legend labels with percentages
percentages = ['{0} - {1:1.1f}%'.format(label, size) for label, size in zip(labels, sizes)]

# Add a legend with custom labels
plt.legend(labels=percentages, loc="upper right", bbox_to_anchor=(1.5, 1))

plt.savefig('Precentage of emissions from different sources.jpg', bbox_inches='tight')

# Show the plot
plt.show()

# %% [markdown]
# Let's explore correlations between total emissions and sector-wise emissions to understand how changes in one sector may affect overall emissions.

# %%
import seaborn as sns

# Calculate correlation matrix
correlation_matrix = sector_df.corr()

# Plot heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Correlation Heatmap between Total Emissions and Sector-wise Emissions')
plt.xlabel('Sectors')
plt.ylabel('Sectors')
plt.savefig('correlation heatmap.jpg', bbox_inches='tight')

plt.show()

# %% [markdown]
# Hypothesis Testing: use t-test to assess statistical significant of the correlation coefficient between the sectors with the strongest correlations

# %%
from scipy.stats import t

# Define the pairs of variables where I found the strongest correlations
variable_pairs = [('2. Industrial Processes', '5. Forest and Land Use'),
                  ('1. Emissions from fuel combustion', '3. Agriculture'),
                  ('2. Industrial Processes', '4. Waste'),
                  ('4. Waste', '5. Forest and Land Use')]

# Set the significance level
alpha = 0.05

# Get the sample size
n = len(sector_df)

# Loop through each pair of variables
for pair in variable_pairs:
    # Extract the correlation coefficient from the correlation matrix
    correlation_coefficient = correlation_matrix.loc[pair[0], pair[1]]
    
    # Compute the t-statistic
    t_statistic = correlation_coefficient * np.sqrt(n - 2) / np.sqrt(1 - correlation_coefficient**2)

    # Calculate the critical value for a two-tailed test
    degrees_of_freedom = n - 2
    critical_value = t.ppf(1 - alpha / 2, degrees_of_freedom)

    # Compare the t-statistic to the critical value
    if np.abs(t_statistic) > critical_value:
        print(f"The correlation between {pair[0]} and {pair[1]} is statistically significant.")
    else:
        print(f"The correlation between {pair[0]} and {pair[1]} is not statistically significant.")
# Out:
# The correlation between 2. Industrial Processes and 5. Forest and Land Use is statistically significant.
# The correlation between 1. Emissions from fuel combustion and 3. Agriculture is statistically significant.
# The correlation between 2. Industrial Processes and 4. Waste is statistically significant.
# The correlation between 4. Waste and 5. Forest and Land Use is statistically significant.

# %% [markdown]
# Let's plot the data:

# %%
fig, axes = plt.subplots(2, 2, figsize=(12, 8),wspace=0.4)

sns.regplot(x='2. Industrial Processes',y='5. Forest and Land Use', data=sector_df, ci=None, ax=axes[0, 0])

sns.regplot(x='1. Emissions from fuel combustion',y='3. Agriculture', data=sector_df, ci=None, ax=axes[0, 1])

sns.regplot(x='2. Industrial Processes',y='4. Waste', data=sector_df, ci=None, ax=axes[1, 0])

sns.regplot(x='4. Waste',y='5. Forest and Land Use', data=sector_df, ci=None, ax=axes[1, 1])

plt.show()
plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 fig, axes = plt.subplots(2, 2, figsize=(12, 8),wspace=0.4)
#       3 sns.regplot(x='2. Industrial Processes',y='5. Forest and Land Use', data=sector_df, ci=None, ax=axes[0, 0])
#       5 sns.regplot(x='1. Emissions from fuel combustion',y='3. Agriculture', data=sector_df, ci=None, ax=axes[0, 1])
#
# File ~/miniconda3/lib/python3.12/site-packages/matplotlib/pyplot.py:1613, in subplots(nrows, ncols, sharex, sharey, squeeze, width_ratios, height_ratios, subplot_kw, gridspec_kw, **fig_kw)
#    1459 def subplots(
#    1460     nrows: int = 1, ncols: int = 1, *,
#    1461     sharex: bool | Literal["none", "all", "row", "col"] = False,
#    (...)
#    1468     **fig_kw
#    1469 ) -> tuple[Figure, Any]:
#    1470     """
#    1471     Create a figure and a set of subplots.
#    1472
#    (...)
#    1611
#    1612     """
# -> 1613     fig = figure(**fig_kw)
#    1614     axs = fig.subplots(nrows=nrows, ncols=ncols, sharex=sharex, sharey=sharey,
#    1615                        squeeze=squeeze, subplot_kw=subplot_kw,
#    1616                        gridspec_kw=gridspec_kw, height_ratios=height_ratios,
#    1617                        width_ratios=width_ratios)
#    1618     return fig, axs
#
# File ~/miniconda3/lib/python3.12/site-packages/matplotlib/pyplot.py:934, in figure(num, figsize, dpi, facecolor, edgecolor, frameon, FigureClass, clear, **kwargs)
#     924 if len(allnums) == max_open_warning >= 1:
#     925     _api.warn_external(
#     926         f"More than {max_open_warning} figures have been opened. "
#     927         f"Figures created through the pyplot interface "
#    (...)
#     931         f"Consider using `matplotlib.pyplot.close()`.",
#     932         RuntimeWarning)
# --> 934 manager = new_figure_manager(
#     935     num, figsize=figsize, dpi=dpi,
#     936     facecolor=facecolor, edgecolor=edgecolor, frameon=frameon,
#     937     FigureClass=FigureClass, **kwargs)
#     938 fig = manager.canvas.figure
#     939 if fig_label:
#
# File ~/miniconda3/lib/python3.12/site-packages/matplotlib/pyplot.py:465, in new_figure_manager(*args, **kwargs)
#     463 """Create a new figure manager instance."""
#     464 _warn_if_gui_out_of_main_thread()
# --> 465 return _get_backend_mod().new_figure_manager(*args, **kwargs)
#
# File ~/miniconda3/lib/python3.12/site-packages/matplotlib_inline/backend_inline.py:27, in new_figure_manager(num, FigureClass, *args, **kwargs)
#      21 def new_figure_manager(num, *args, FigureClass=Figure, **kwargs):
#      22     """
#      23     Return a new figure manager for a new figure instance.
#      24
#      25     This function is part of the API expected by Matplotlib backends.
#      26     """
# ---> 27     return new_figure_manager_given_figure(num, FigureClass(*args, **kwargs))
#
# File ~/miniconda3/lib/python3.12/site-packages/matplotlib/figure.py:2494, in Figure.__init__(self, figsize, dpi, facecolor, edgecolor, linewidth, frameon, subplotpars, tight_layout, constrained_layout, layout, **kwargs)
#    2398 def __init__(self,
#    2399              figsize=None,
#    2400              dpi=None,
#    (...)
#    2410              **kwargs
#    2411              ):
#    2412     """
#    2413     Parameters
#    2414     ----------
#    (...)
#    2492         %(Figure:kwdoc)s
#    2493     """
# -> 2494     super().__init__(**kwargs)
#    2495     self.figure = self
#    2496     self._layout_engine = None
#
# File ~/miniconda3/lib/python3.12/site-packages/matplotlib/figure.py:213, in FigureBase.__init__(self, **kwargs)
#     211 self.stale = True
#     212 self.suppressComposite = None
# --> 213 self.set(**kwargs)
#
# File ~/miniconda3/lib/python3.12/site-packages/matplotlib/artist.py:147, in Artist.__init_subclass__.<locals>.<lambda>(self, **kwargs)
#     139 if not hasattr(cls.set, '_autogenerated_signature'):
#     140     # Don't overwrite cls.set if the subclass or one of its parents
#     141     # has defined a set method set itself.
#     142     # If there was no explicit definition, cls.set is inherited from
#     143     # the hierarchy of auto-generated set methods, which hold the
#     144     # flag _autogenerated_signature.
#     145     return
# --> 147 cls.set = lambda self, **kwargs: Artist.set(self, **kwargs)
#     148 cls.set.__name__ = "set"
#     149 cls.set.__qualname__ = f"{cls.__qualname__}.set"
#
# File ~/miniconda3/lib/python3.12/site-packages/matplotlib/artist.py:1227, in Artist.set(self, **kwargs)
#    1223 def set(self, **kwargs):
#    1224     # docstring and signature are auto-generated via
#    1225     # Artist._update_set_signature_and_docstring() at the end of the
#    1226     # module.
# -> 1227     return self._internal_update(cbook.normalize_kwargs(kwargs, self))
#
# File ~/miniconda3/lib/python3.12/site-packages/matplotlib/artist.py:1219, in Artist._internal_update(self, kwargs)
#    1212 def _internal_update(self, kwargs):
#    1213     """
#    1214     Update artist properties without prenormalizing them, but generating
#    1215     errors as if calling `set`.
#    1216
#    1217     The lack of prenormalization is to maintain backcompatibility.
#    1218     """
# -> 1219     return self._update_props(
#    1220         kwargs, "{cls.__name__}.set() got an unexpected keyword argument "
#    1221         "{prop_name!r}")
#
# File ~/miniconda3/lib/python3.12/site-packages/matplotlib/artist.py:1193, in Artist._update_props(self, props, errfmt)
#    1191             func = getattr(self, f"set_{k}", None)
#    1192             if not callable(func):
# -> 1193                 raise AttributeError(
#    1194                     errfmt.format(cls=type(self), prop_name=k))
#    1195             ret.append(func(v))
#    1196 if ret:
#
# AttributeError: Figure.set() got an unexpected keyword argument 'wspace'
